# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

# %%
from src.circuit_builder import random_brickwork_circuit

# %%
# Create circuit using src functions
circuit = random_brickwork_circuit(6, 0.0)

# Draw circuit (matplotlib)
circuit.draw("mpl")
